# %%
import pandas as pd
import numpy as np

# %%
df_leak = pd.read_csv("test_matches.csv")

# %%
df_leak.head()
# Out:
#                               Extra                                  Test  \
# 0    ENSG00000001497_44431_556_B9_1  7729b27c-bacc-11e8-b2b8-ac1f6b6435d0
# 1    ENSG00000006194_35086_383_E8_7  5661665e-bacf-11e8-b2b8-ac1f6b6435d0
# 2   ENSG00000008324_47377_688_E7_10  b029f372-bad9-11e8-b2b9-ac1f6b6435d0
# 3  ENSG00000019186_63771_1414_D12_2  adc182fa-bad2-11e8-b2b8-ac1f6b6435d0
# 4   ENSG00000025770_67932_1255_A3_4  39508fe6-bad3-11e8-b2b8-ac1f6b6435d0
#
#    SimR  SimG  SimB   Target Target_noisey
# 0    10     6     2  25 18 0           NaN
# 1     0     0     0  25 17 0           NaN
# 2     2     0     2     23 2           NaN
# 3     6     2     0  23 0 21           NaN
# 4     0     0     0     16 0           NaN

# %%
#fn_orig = 'protein_classification_t_ResNext50_ext_rgby_512_4e-4.csv' # 0.562
path = '../submit/'
fn_orig = 'HPAC_th_manual_3_resnext50_rgb_aug005_a4_tta16.csv' 

df_orig = pd.read_csv(path + fn_orig)
df_orig
# Out:
#                                          Id  Predicted
# 0      00008af0-bad0-11e8-b2b8-ac1f6b6435d0          2
# 1      0000a892-bacf-11e8-b2b8-ac1f6b6435d0       5 25
# 2      0006faa6-bac7-11e8-b2b7-ac1f6b6435d0  0 5 21 25
# 3      0008baca-bad7-11e8-b2b9-ac1f6b6435d0       0 25
# 4      000cce7e-bad4-11e8-b2b8-ac1f6b6435d0    0 23 25
# 5      00109f6a-bac8-11e8-b2b7-ac1f6b6435d0    4 21 25
# 6      001765de-bacd-11e8-b2b8-ac1f6b6435d0     0 4 25
# 7      0018641a-bac9-11e8-b2b8-ac1f6b6435d0       0 25
# 8      00200f22-bad7-11e8-b2b9-ac1f6b6435d0          0
# 9      0026f154-bac6-11e8-b2b7-ac1f6b6435d0         25
# 10     002729d2-bace-11e8-b2b8-ac1f6b6435d0      18 25
# 11     002c1a7c-bad4-11e8-b2b8-ac1f6b6435d0        3 5
# 12     003170fa-bacd-11e8-b2b8-ac1f6b6435d0       2 25
# 13     0031820a-baca-11e8-b2b8-ac1f6b6435d0       7 25
# 14     00407c16-bad3-11e8-b2b8-ac1f6b6435d0         25
# 15     005ce2ea-bacc-11e8-b2b8-ac1f6b6435d0      18 25
# ...

# %%
from IPython.core.debugger import set_trace
len(df_leak['Test'])
leakList = list(df_leak['Test'])

for idx, i in enumerate(leakList):
    try:
        df_orig.loc[df_orig['Id']==i,'Predicted'] = \
        df_leak.loc[df_leak['Test']==i,'Target'].item()
    except:
        set_trace()

# %%
df_orig.to_csv(path + 'leak_' + fn_orig, header=True, index=False)
